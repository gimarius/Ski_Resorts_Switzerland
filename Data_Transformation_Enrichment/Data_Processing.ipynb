# %% [markdown]
# ## Dataset Skiresort.ch

# %%
import pandas as pd

# %%
data = pd.read_csv('Data/Output_Skiresort_ch.csv')
df = data.copy()
df.head()
# Out:
#                                                    0
# 0  Arosa Lenzerheide\nEuropa Schweiz Ostschweiz G...
# 1  Aletsch Arena – Riederalp/Bettmeralp/Fiesch Eg...
# 2  Ischgl/Samnaun – Silvretta Arena\nEuropa Öster...
# 3  Hohsaas – Saas-Grund\nEuropa Schweiz Genfersee...
# 4  Wildhaus – Gamserrugg (Toggenburg)\nEuropa Sch...

# %%
df.columns = ['Name']
df = df.replace('\n',';', regex=True)
df= df.Name.str.split(";", expand = True)
df.columns = ['Name', "Region", "Ergebnis", "Hoehe", "Pisten_km", "blaue_Piste", "rote_Piste", "schwarze_Piste", "Anzahl_Bahnen", "Preis", "Test_1", "Test_2", "Test_3"]
dictionary = {'–':'-', 'ä':'a', 'ö': 'o', 'ü':'ue', 'Ö': 'Oe', 'é':'e', 'è': 'e', 'à': 'a'}
df.replace(dictionary, regex=True, inplace=True)

# %%
df.head()
# Out:
#                                                 Name  \
# 0                                  Arosa Lenzerheide
# 1  Aletsch Arena - Riederalp/Bettmeralp/Fiesch Eg...
# 2                   Ischgl/Samnaun - Silvretta Arena
# 3                               Hohsaas - Saas-Grund
# 4                 Wildhaus - Gamserrugg (Toggenburg)
#
#                                               Region  \
# 0        Europa Schweiz Ostschweiz Graubuenden Arosa
# 1  Europa Schweiz Genferseeregion Wallis Aletsch ...
# 2  Europa Oesterreich Tirol Tiroler Oberland Land...
# 3  Europa Schweiz Genferseeregion Wallis Saas-Fee...
# 4    Europa Schweiz Ostschweiz St. Gallen Toggenburg
#
#                                             Ergebnis  \
# 0  Europa Schweiz Ostschweiz Graubuenden Lenzerheide
# 1                                       Testergebnis
# 2  Europa Schweiz Ostschweiz Graubuenden Engadin ...
# 3                                       Testergebnis
# 4                                       Testergebnis
#
#                       Hoehe                 Pisten_km blaue_Piste rote_Piste  \
# 0              Testergebnis  1636 m (1229 m - 2865 m)      225 km     110 km
# 1  1024 m (1845 m - 2869 m)                    104 km       42 km      50 km
# 2              Testergebnis  1512 m (1360 m - 2872 m)      239 km      47 km
# 3  1641 m (1559 m - 3200 m)                   29,5 km      7,5 km      21 km
# 4  1056 m (1020 m - 2076 m)                     23 km        3 km      17 km
#
#   schwarze_Piste    Anzahl_Bahnen                   Preis  \
# 0          87 km            28 km         43 Lifte/Bahnen
# 1          12 km  35 Lifte/Bahnen  SFr. 66,- / ca. € 66,-
# 2         143 km            49 km         41 Lifte/Bahnen
# 3           1 km   7 Lifte/Bahnen  SFr. 59,- / ca. € 59,-
# 4           3 km   6 Lifte/Bahnen  SFr. 58,- / ca. € 58,-
#
#                    Test_1   Test_2 Test_3
# 0  SFr. 84,- / ca. € 84,-  Details   None
# 1                 Details     None   None
# 2                  € 67,-  Details   None
# 3                 Details     None   None
# 4                 Details     None   None

# %%
df.to_excel('Processed_Data/Processed_Data_Skiresort_ch.xlsx', index=False)

# %% [markdown]
# ## Dataset MySwitzerland

# %%
data = pd.read_csv('Data/Output_Skiresort_MySwitzerland.csv')
df = data.copy()
df.head()

# %%
df.columns = ['Name']
df = df.replace('\n',';', regex=True)
df= df.Name.str.split(";", expand = True)
df.columns = ['Name', "Region", "Wetter", "Grad", "Wetter_1", "Wetter_2", "Schneehöhe", "Schneehöhe_1", "Schneehöhe_2", "Tageskarten", "Preis", "Preis_Kinder"]
# Out:
#                                                   Name
# 0    Verbier\nVerbier - Wallis\nWetterprognose heut...
# 1    Thyon - 4 Vallées\nLes Collons Thyon - Wallis\...
# 2    Samnaun/Ischgl\nSamnaun - Graubünden\nWetterpr...
# 3    Engadin St.Moritz\nSt. Moritz - Graubünden\nWe...
# 4                                              Anzeige
# ..                                                 ...
# 264  Langlauf\nAlles über Langlauf in der Schweiz\n...
# 265  Bulle - La Chia\nBulle - Fribourg Region\nWett...
# 266  Eischoll\nEischoll - Wallis\nWetterprognose he...
# 267  Flüelen-Eggberge\nAltdorf - Luzern - Vierwalds...
# 268  Obermutten\nObermutten - Graubünden\nKeine akt...
#
# [269 rows x 1 columns]

# %%
df.to_excel('Data_MySwitzerland.xlsx', index=False)
