# %%
import pandas as pd

# %% [markdown]
# ## Geo-Data from Swiss Post
#
# Data ist from here:
#
# https://swisspost.opendatasoft.com/explore/dataset/plz_verzeichnis_v2/information/?disjunctive.postleitzahl&location=8,46.88892,8.29742&dataChart=...%3D%3D

# %%
data = pd.read_excel('PLZ_Verzeichnis_Post.xlsx')
data.head()
# Out:
#    REC_ART  ONRP  BFSNR  PLZ_TYP  POSTLEITZAHL  PLZ_ZZ  GPLZ  \
# 0        1   111   5586       80          1000       7  1000
# 1        1   118   5586       80          1000      17  1000
# 2        1   119   5586       80          1000      19  1000
# 3        1   120   5586       80          1000      20  1000
# 4        1   122   5586       80          1000      22  1000
#
#            ORTBEZ18          ORTBEZ27 KANTON  SPRACHCODE  SPRACHCODE_ ABW  \
# 0  Lausanne St-Paul  Lausanne St-Paul     VD           2              NaN
# 1       Lausanne 17       Lausanne 17     VD           2              NaN
# 2       Lausanne 19       Lausanne 19     VD           2              NaN
# 3  Lausanne Sévelin  Lausanne Sévelin     VD           2              NaN
# 4       Lausanne 22       Lausanne 22     VD           2              NaN
#
#    BRIEFZ_DURCH GILT_AB_DAT  PLZ_BRIEFZUST PLZ_COFF Geo Shape Geokoordinaten
# 0           130  1993-09-28         100060      NaN       NaN            NaN
# 1           130  1986-05-21         100060      NaN       NaN            NaN
# 2           130  1993-09-28         100060      NaN       NaN            NaN
# 3           130  1993-09-06         100060      NaN       NaN            NaN
# 4           130  1986-05-21         100060      NaN       NaN            NaN

# %% [markdown]
# Transform the data

# %%
df = data.copy()
df = df[['POSTLEITZAHL','KANTON', 'SPRACHCODE','Geo Shape', 'Geokoordinaten']]
df = df.dropna(subset=['Geokoordinaten']) 
df = df.rename({'POSTLEITZAHL': 'PLZ'}, axis=1)
df = df.rename({'KANTON': 'Kanton_Kuerzel'}, axis=1)
df = df.drop_duplicates(subset=['PLZ'])
df[['Breitengrad', 'Längengrad']] = df.Geokoordinaten.str.split(",", expand = True)
df.drop('Geokoordinaten', axis=1, inplace=True)
df.head()
# Out:
#      PLZ Kanton_Kuerzel  SPRACHCODE  \
# 7   1006             VD           2
# 8   1007             VD           2
# 9   1010             VD           2
# 10  1012             VD           2
# 13  1023             VD           2
#
#                                             Geo Shape        Breitengrad  \
# 7   {"coordinates":[[[6.640617419781327,46.4548727...  46.49118284131651
# 8   {"coordinates":[[[6.585057297060006,46.4555754...  46.48798204323823
# 9   {"coordinates":[[[6.670121608565141,46.5322058...  46.53774592901061
# 10  {"coordinates":[[[6.654156949088971,46.5180884...  46.52714673079724
# 13  {"coordinates":[[[6.577351801130968,46.5385330...  46.55632346032437
#
#              Längengrad
# 7     6.634896570436528
# 8     6.607035070914438
# 9    6.6552615250679015
# 10   6.6565596305451775
# 13    6.577725498438854

# %% [markdown]
# ## Data from Skiresort.de

# %%
skiresort_data_import = pd.read_excel('MASTER_Bergfex_data.xlsx')
skiresort_data = skiresort_data_import.copy()
skiresort_data.head()
# Out:
#    ID  Skiresort_ID             Skigebiet_Name      Kanton               Ort  \
# 0   1           2.0                  Adelboden        Bern         Adelboden
# 1  49          83.0  Engstligenalp - Adelboden        Bern         Adelboden
# 2   3         203.0                     Aeschi        Bern  Aeschi bei Spiez
# 3   4           8.0           Airolo - Pesciüm      Tessin            Airolo
# 4   7          17.0                      Amden  St. Gallen             Amden
#
#       Land   PLZ  Min_Höhe  Max_Höhe  Total_Pisten_Km  blaue_Piste_km  \
# 0  Schweiz  3715      1260      2200             86.0            46.0
# 1  Schweiz  3715      1971      2353             17.0             7.0
# 2  Schweiz  3703       860       890              0.2             0.2
# 3  Schweiz  6780      1175      2250             30.0             1.0
# 4  Schweiz  8873       931      1684             20.0            10.0
#
#    rote_Piste_km  schwarze_Piste_km  Anzahl_Bahnen  Preis in CHF
# 0           34.0                6.0             25          70.0
# 1            6.0                4.0              8          55.0
# 2            0.0                0.0              1          15.0
# 3           15.0               14.0              8           0.0
# 4           10.0                0.0              6          38.0

# %% [markdown]
# ## Join the Data
# Left join on the column 'PLZ'

# %%
merge = pd.merge(skiresort_data, df, on='PLZ', how='left')
merge.head()
# Out:
#    ID  Skiresort_ID             Skigebiet_Name      Kanton               Ort  \
# 0   1           2.0                  Adelboden        Bern         Adelboden
# 1  49          83.0  Engstligenalp - Adelboden        Bern         Adelboden
# 2   3         203.0                     Aeschi        Bern  Aeschi bei Spiez
# 3   4           8.0           Airolo - Pesciüm      Tessin            Airolo
# 4   7          17.0                      Amden  St. Gallen             Amden
#
#       Land   PLZ  Min_Höhe  Max_Höhe  Total_Pisten_Km  blaue_Piste_km  \
# 0  Schweiz  3715      1260      2200             86.0            46.0
# 1  Schweiz  3715      1971      2353             17.0             7.0
# 2  Schweiz  3703       860       890              0.2             0.2
# 3  Schweiz  6780      1175      2250             30.0             1.0
# 4  Schweiz  8873       931      1684             20.0            10.0
#
#    rote_Piste_km  schwarze_Piste_km  Anzahl_Bahnen  Preis in CHF  \
# 0           34.0                6.0             25          70.0
# 1            6.0                4.0              8          55.0
# 2            0.0                0.0              1          15.0
# 3           15.0               14.0              8           0.0
# 4           10.0                0.0              6          38.0
#
#   Kanton_Kuerzel  SPRACHCODE  \
# 0             BE           1
# 1             BE           1
# 2             BE           1
# 3             TI           3
# 4             SG           1
#
#                                            Geo Shape         Breitengrad  \
# 0  {"coordinates":[[[7.556297221810153,46.4136636...   46.47362091585067
# 1  {"coordinates":[[[7.556297221810153,46.4136636...   46.47362091585067
# 2  {"coordinates":[[[7.702246806277913,46.6379152...   46.65429334721316
# 3  {"coordinates":[[[8.62939138876246,46.52450327...   46.52724920112436
# 4  {"coordinates":[[[9.189869575108307,47.1236998...  47.159937277478924
#
#             Längengrad
# 0   7.5551545844706895
# 1   7.5551545844706895
# 2    7.698838241205742
# 3     8.63064800879524
# 4    9.167879637010529

# %%
merge.count()
# Out:
# ID                   166
# Skiresort_ID         163
# Skigebiet_Name       166
# Kanton               166
# Ort                  166
# Land                 166
# PLZ                  166
# Min_Höhe             166
# Max_Höhe             166
# Total_Pisten_Km      166
# blaue_Piste_km       166
# rote_Piste_km        166
# schwarze_Piste_km    166
# Anzahl_Bahnen        166
# Preis in CHF         166
# Kanton_Kuerzel       166
# SPRACHCODE           166
# Geo Shape            166
# Breitengrad          166
# Längengrad           166
# dtype: int64

# %% [markdown]
# ## Merge sucessful

# %%
merge.to_excel('Data_Skiresorts_Final.xlsx', index=False)
